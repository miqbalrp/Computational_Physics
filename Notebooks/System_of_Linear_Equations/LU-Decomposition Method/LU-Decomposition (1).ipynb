# %% [markdown]
# ## Define Decomposition Function

# %%
def decomposition(A):
  # get number of rows from A
  n = len(A)

  # create zeros matrix of L and U
  L = [[0 for row in range(n)]
       for col in range(n)]
  U = [[0 for row in range(n)]
       for col in range(n)]
  
  for p in range(n):
    # upper matrix
    for j in range(p,n):
      # summation of L(p,k)*U(k,j)
      sum = 0
      for k in range(p):
        sum = sum + L[p][k]*U[k][j]
      U[p][j] = A[p][j] - sum

    # lower matrix
    q = p
    for i in range (q,n):
      if (i==q):
        # diagonal of L
        L[i][q]=1
      else:
        # summation of L(i,k)*U(k,q)
        sum = 0
        for k in range(q):
          sum = sum + L[i][k]*U[k][q]
        L[i][q] = (A[i][q] - sum)/U[q][q]

  return L, U

# %% [markdown]
# ## Define Function for Showing Matrix Element

# %%
def show(matrix):
  n = len(A)
  for row in range(n):
    for col in range(n):
      print('%.2f' % matrix[row][col], end="\t")
    print("")

# %% [markdown]
# ## Calculate Matrix L and U

# %%
# matrix A
A = [[3, 2, -1],
     [2, -2, 4],
     [-1, 0.5, -1]]

# calculate L and U     
L, U = decomposition(A)

# show L and U
print("Matrix L :")
show(L)

print("\nMatrix U :")
show(U)
# Out:
# Matrix L :
# 1.00	0.00	0.00
# 0.67	1.00	0.00
# -0.33	-0.35	1.00
#
# Matrix U :
# 3.00	2.00	-1.00
# 0.00	-3.33	4.67
# 0.00	0.00	0.30
